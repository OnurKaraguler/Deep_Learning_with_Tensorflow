# %%
from tensorflow.python.compiler.mlcompute import mlcompute
mlcompute.set_mlc_device(device_name='gpu')
# Out:
# WARNING:tensorflow:Eager mode uses the CPU. Switching to the CPU.

# %%
import os
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'    # ignore information messages

import tensorflow as tf
from tensorflow.keras import Sequential, Input, Model, callbacks
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import relu
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import (SparseCategoricalAccuracy, Precision, Recall, AUC, 
                                      FalsePositives, FalseNegatives, TruePositives, TrueNegatives)

import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import mnist    # 28x28 images of hand_written digits 0-9

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
img_height = img_width = 28
def resize_images(img):
    img = cv2.resize(img, (img_height, img_width))
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)    # to read images grayscale
    img = np.reshape(img, (img_height, img_width, 1))
    return img

# %%
x_train = np.array([resize_images(img) for img in x_train])
x_test = np.array([resize_images(img) for img in x_test])

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img

for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(array_to_img(x_train[i]))
plt.show()

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# ## train a network (basic approach)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
# model.fit(x_train, y_train, epochs=3)

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4061 - accuracy: 0.8814 - val_loss: 0.1284 - val_accuracy: 0.9585
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1018 - accuracy: 0.9697 - val_loss: 0.0964 - val_accuracy: 0.9708
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0656 - accuracy: 0.9791 - val_loss: 0.0853 - val_accuracy: 0.9732
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0498 - accuracy: 0.9836 - val_loss: 0.0797 - val_accuracy: 0.9757
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0390 - accuracy: 0.9873 - val_loss: 0.0917 - val_accuracy: 0.9724
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0305 - accuracy: 0.9893 - val_loss: 0.0797 - val_accuracy: 0.9775
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.0858 - val_accuracy: 0.9764
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.1024 - val_accuracy: 0.9756
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.0834 - val_accuracy: 0.9803
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 0.1012 - val_accuracy: 0.9767

# %%
# val_loss, val_acc = model.evaluate(x_test, y_test)

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## train a network (convolutional approach)

# %%
inputs = Input(shape=(28, 28, 1))
x = Conv2D(32, 3)(inputs)
x = BatchNormalization()(x)
x = relu(x)
x = MaxPooling2D()(x)
x = Conv2D(64, 3)(x)
x = BatchNormalization()(x)
x = relu(x)
x = MaxPooling2D()(x)
x = Conv2D(128, 3)(x)
x = BatchNormalization()(x)
x = relu(x)
x = Flatten()(x)
x = Dense(64, activation="relu")(x)
outputs = Dense(10, activation="sigmoid")(x)
model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam',
             loss=SparseCategoricalCrossentropy(),
             metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1750 - accuracy: 0.9454 - val_loss: 0.0430 - val_accuracy: 0.9867
# Epoch 2/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0404 - accuracy: 0.9878 - val_loss: 0.0329 - val_accuracy: 0.9895
# Epoch 3/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.0298 - val_accuracy: 0.9909
# Epoch 4/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0225 - val_accuracy: 0.9927
# Epoch 5/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0239 - val_accuracy: 0.9927
# Epoch 6/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0245 - val_accuracy: 0.9930
# Epoch 7/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0277 - val_accuracy: 0.9930
# Epoch 8/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0265 - val_accuracy: 0.9925
# Epoch 9/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0339 - val_accuracy: 0.9917
# Epoch 10/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0286 - val_accuracy: 0.9931
# Epoch 11/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0397 - val_accuracy: 0.9915
# Epoch 12/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0304 - val_accuracy: 0.9933
# Epoch 13/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0348 - val_accuracy: 0.9920
# Epoch 14/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.0315 - val_accuracy: 0.9932
# Epoch 15/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0343 - val_accuracy: 0.9926
# Epoch 16/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0372 - val_accuracy: 0.9926
# Epoch 17/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0316 - val_accuracy: 0.9933
# Epoch 18/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0426 - val_accuracy: 0.9916
# Epoch 19/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0312 - val_accuracy: 0.9926
# Epoch 20/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0376 - val_accuracy: 0.9935
# Epoch 21/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0479 - val_accuracy: 0.9916
# Epoch 22/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0449 - val_accuracy: 0.9911
# Epoch 23/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0527 - val_accuracy: 0.9907
# Epoch 24/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0550 - val_accuracy: 0.9894
# Epoch 25/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0512 - val_accuracy: 0.9919
# Epoch 26/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 8.0672e-04 - accuracy: 0.9997 - val_loss: 0.0361 - val_accuracy: 0.9935
# Epoch 27/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0450 - val_accuracy: 0.9925
# Epoch 28/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0486 - val_accuracy: 0.9922
# Epoch 29/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0452 - val_accuracy: 0.9933
# Epoch 30/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0434 - val_accuracy: 0.9930

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model = Sequential([
    Conv2D(32, 3, activation='relu', input_shape=(28, 28, 1)),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.5),
    Conv2D(64, 3, activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.5),
    Conv2D(128, 3, activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.5),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='sigmoid')
])

##################

model.compile(optimizer='adam',
             loss=SparseCategoricalCrossentropy(),
             metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.9185 - accuracy: 0.7073 - val_loss: 0.0853 - val_accuracy: 0.9752
# Epoch 2/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2083 - accuracy: 0.9347 - val_loss: 0.0716 - val_accuracy: 0.9784
# Epoch 3/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1633 - accuracy: 0.9507 - val_loss: 0.0576 - val_accuracy: 0.9823
# Epoch 4/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1395 - accuracy: 0.9567 - val_loss: 0.0526 - val_accuracy: 0.9850
# Epoch 5/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1257 - accuracy: 0.9608 - val_loss: 0.0484 - val_accuracy: 0.9857
# Epoch 6/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1071 - accuracy: 0.9674 - val_loss: 0.0529 - val_accuracy: 0.9850
# Epoch 7/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1127 - accuracy: 0.9652 - val_loss: 0.0463 - val_accuracy: 0.9872
# Epoch 8/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1034 - accuracy: 0.9681 - val_loss: 0.0465 - val_accuracy: 0.9866
# Epoch 9/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0987 - accuracy: 0.9700 - val_loss: 0.0446 - val_accuracy: 0.9869
# Epoch 10/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0958 - accuracy: 0.9696 - val_loss: 0.0455 - val_accuracy: 0.9871
# Epoch 11/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0913 - accuracy: 0.9715 - val_loss: 0.0445 - val_accuracy: 0.9878
# Epoch 12/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0872 - accuracy: 0.9727 - val_loss: 0.0420 - val_accuracy: 0.9889
# Epoch 13/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0885 - accuracy: 0.9719 - val_loss: 0.0410 - val_accuracy: 0.9893
# Epoch 14/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0822 - accuracy: 0.9749 - val_loss: 0.0436 - val_accuracy: 0.9888
# Epoch 15/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0806 - accuracy: 0.9743 - val_loss: 0.0391 - val_accuracy: 0.9884
# Epoch 16/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0820 - accuracy: 0.9739 - val_loss: 0.0377 - val_accuracy: 0.9889
# Epoch 17/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0764 - accuracy: 0.9763 - val_loss: 0.0367 - val_accuracy: 0.9896
# Epoch 18/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0789 - accuracy: 0.9754 - val_loss: 0.0403 - val_accuracy: 0.9892
# Epoch 19/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0798 - accuracy: 0.9757 - val_loss: 0.0368 - val_accuracy: 0.9903
# Epoch 20/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0786 - accuracy: 0.9756 - val_loss: 0.0408 - val_accuracy: 0.9889
# Epoch 21/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0775 - accuracy: 0.9759 - val_loss: 0.0340 - val_accuracy: 0.9909
# Epoch 22/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0701 - accuracy: 0.9782 - val_loss: 0.0387 - val_accuracy: 0.9892
# Epoch 23/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0741 - accuracy: 0.9768 - val_loss: 0.0366 - val_accuracy: 0.9904
# Epoch 24/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0699 - accuracy: 0.9781 - val_loss: 0.0334 - val_accuracy: 0.9908
# Epoch 25/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0710 - accuracy: 0.9776 - val_loss: 0.0367 - val_accuracy: 0.9900
# Epoch 26/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0701 - accuracy: 0.9791 - val_loss: 0.0329 - val_accuracy: 0.9910
# Epoch 27/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0699 - accuracy: 0.9771 - val_loss: 0.0357 - val_accuracy: 0.9900
# Epoch 28/30
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0720 - accuracy: 0.9765 - val_loss: 0.0327 - val_accuracy: 0.9916
# Epoch 29/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0661 - accuracy: 0.9787 - val_loss: 0.0339 - val_accuracy: 0.9909
# Epoch 30/30
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0691 - accuracy: 0.9786 - val_loss: 0.0344 - val_accuracy: 0.9903

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.save('mnist_saved.model')
# Out:
# /Users/onurkaraguler/miniforge3/envs/ml/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /Users/onurkaraguler/miniforge3/envs/ml/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:1397: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: mnist_saved.model/assets

# %%
model = load_model('mnist_saved.model')

# %%
y_predicted = model.predict(x_test)

# %%
num = 77
y_predicted[num]
print('predicted: ', np.argmax(y_predicted[num]))

print('truth: ', y_test[num])

plt.imshow(x_test[num], cmap=plt.cm.binary)
plt.show()
# print(x_train[0])
# Out:
# predicted:  2
# truth:  2

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 972,    1,    2,    0,    0,    0,    1,    3,    0,    1],
#        [   0, 1132,    0,    0,    0,    0,    1,    2,    0,    0],
#        [   1,    0, 1015,    1,    1,    0,    1,   13,    0,    0],
#        [   0,    0,    2, 1000,    0,    5,    0,    2,    1,    0],
#        [   1,    0,    1,    0,  972,    0,    4,    1,    0,    3],
#        [   2,    0,    0,    4,    0,  884,    1,    1,    0,    0],
#        [   3,    3,    0,    0,    1,    2,  949,    0,    0,    0],
#        [   0,    2,    4,    0,    0,    1,    0, 1021,    0,    0],
#        [   0,    0,    1,    1,    2,    1,    0,    1,  967,    1],
#        [   1,    0,    0,    0,    3,    3,    0,    6,    5,  991]],
#       dtype=int32)>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
